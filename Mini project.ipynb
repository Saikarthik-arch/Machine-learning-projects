# %% [markdown]
# ## Mini Project One

# %%
import pandas as pd

# %%
reading the file

# %%
df= pd.read_csv('data.csv')
df
# Out:
#                   city  Temperature_C  Humidity Condition
# 0    01/01/25 Hyderbad           21.0      60.0       NaN
# 1    01/01/25 Hyderbad           21.0      50.0    cloudy
# 2    01/01/25 Hyderbad            NaN      40.0       NaN
# 3    01/01/25 Hyderbad           32.0      30.0    cloudy
# 4    01/01/25 Hyderbad           67.0      60.0       NaN
# 5    01/01/25 Hyderbad           34.0       NaN    cloudy
# 6    01/01/25 Hyderbad            NaN      45.0    cloudy
# 7    01/01/25 Hyderbad           32.0       NaN    cloudy
# 8    01/01/25 Hyderbad           45.0      34.0     sunny
# 9    01/01/25 Hyderbad           54.0      23.0     sunny
# 10   01/01/25 Hyderbad            NaN      67.0    cloudy

# %%
df.isnull()
# Out:
#      city  Temperature_C  Humidity  Condition
# 0   False          False     False       True
# 1   False          False     False      False
# 2   False           True     False       True
# 3   False          False     False      False
# 4   False          False     False       True
# 5   False          False      True      False
# 6   False           True     False      False
# 7   False          False      True      False
# 8   False          False     False      False
# 9   False          False     False      False
# 10  False           True     False      False

# %%
Exploring data

# %%
df.head()
# Out:
#                  city  Temperature_C  Humidity Condition
# 0   01/01/25 Hyderbad           21.0      60.0       NaN
# 1   01/01/25 Hyderbad           21.0      50.0    cloudy
# 2   01/01/25 Hyderbad            NaN      40.0       NaN
# 3   01/01/25 Hyderbad           32.0      30.0    cloudy
# 4   01/01/25 Hyderbad           67.0      60.0       NaN

# %%
df.tail()
# Out:
#                   city  Temperature_C  Humidity Condition
# 6    01/01/25 Hyderbad            NaN      45.0    cloudy
# 7    01/01/25 Hyderbad           32.0       NaN    cloudy
# 8    01/01/25 Hyderbad           45.0      34.0     sunny
# 9    01/01/25 Hyderbad           54.0      23.0     sunny
# 10   01/01/25 Hyderbad            NaN      67.0    cloudy

# %%
df['Temperature_C']=df['Temperature_C'].fillna(df['Temperature_C'].mean())
df
# Out:
#                   city  Temperature_C  Humidity Condition
# 0    01/01/25 Hyderbad          21.00      60.0       NaN
# 1    01/01/25 Hyderbad          21.00      50.0    cloudy
# 2    01/01/25 Hyderbad          38.25      40.0       NaN
# 3    01/01/25 Hyderbad          32.00      30.0    cloudy
# 4    01/01/25 Hyderbad          67.00      60.0       NaN
# 5    01/01/25 Hyderbad          34.00       NaN    cloudy
# 6    01/01/25 Hyderbad          38.25      45.0    cloudy
# 7    01/01/25 Hyderbad          32.00       NaN    cloudy
# 8    01/01/25 Hyderbad          45.00      34.0     sunny
# 9    01/01/25 Hyderbad          54.00      23.0     sunny
# 10   01/01/25 Hyderbad          38.25      67.0    cloudy

# %%
df['Humidity']=df['Humidity'].fillna(df['Humidity'].sum())

# %%
df
# Out:
#                   city  Temperature_C  Humidity Condition
# 0    01/01/25 Hyderbad          21.00      60.0       NaN
# 1    01/01/25 Hyderbad          21.00      50.0    cloudy
# 2    01/01/25 Hyderbad          38.25      40.0       NaN
# 3    01/01/25 Hyderbad          32.00      30.0    cloudy
# 4    01/01/25 Hyderbad          67.00      60.0       NaN
# 5    01/01/25 Hyderbad          34.00     409.0    cloudy
# 6    01/01/25 Hyderbad          38.25      45.0    cloudy
# 7    01/01/25 Hyderbad          32.00     409.0    cloudy
# 8    01/01/25 Hyderbad          45.00      34.0     sunny
# 9    01/01/25 Hyderbad          54.00      23.0     sunny
# 10   01/01/25 Hyderbad          38.25      67.0    cloudy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   city           11 non-null     object
#  1   Temperature_C  11 non-null     float64
#  2   Humidity       11 non-null     float64
#  3   Condition      8 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 484.0+ bytes

# %%
df.shape
# Out:
# (11, 4)

# %%
df[2:6]
# Out:
#                  city  Temperature_C  Humidity Condition
# 2   01/01/25 Hyderbad          38.25      40.0       NaN
# 3   01/01/25 Hyderbad          32.00      30.0    cloudy
# 4   01/01/25 Hyderbad          67.00      60.0       NaN
# 5   01/01/25 Hyderbad          34.00     409.0    cloudy

# %%
df.columns
# Out:
# Index(['city', 'Temperature_C', 'Humidity', 'Condition'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
df.dtypes
# Out:
# city              object
# Temperature_C    float64
# Humidity         float64
# Condition         object
# dtype: object

# %%
df.city
# Out:
# 0      01/01/25 Hyderbad
# 1      01/01/25 Hyderbad
# 2      01/01/25 Hyderbad
# 3      01/01/25 Hyderbad
# 4      01/01/25 Hyderbad
# 5      01/01/25 Hyderbad
# 6      01/01/25 Hyderbad
# 7      01/01/25 Hyderbad
# 8      01/01/25 Hyderbad
# 9      01/01/25 Hyderbad
# 10     01/01/25 Hyderbad
# Name: city, dtype: object

# %%
df[['city','Humidity']]
# Out:
#                   city  Humidity
# 0    01/01/25 Hyderbad      60.0
# 1    01/01/25 Hyderbad      50.0
# 2    01/01/25 Hyderbad      40.0
# 3    01/01/25 Hyderbad      30.0
# 4    01/01/25 Hyderbad      60.0
# 5    01/01/25 Hyderbad     409.0
# 6    01/01/25 Hyderbad      45.0
# 7    01/01/25 Hyderbad     409.0
# 8    01/01/25 Hyderbad      34.0
# 9    01/01/25 Hyderbad      23.0
# 10   01/01/25 Hyderbad      67.0

# %%
df['city'][df['Condition']=='sunny']
# Out:
# 8     01/01/25 Hyderbad
# 9     01/01/25 Hyderbad
# Name: city, dtype: object

# %%
creating the dataset

# %%
df = pd.DataFrame({
    "name":[ "Pavan", "Kumar", "Anil", "Ravi", "Suresh","Mahesh", "Rohit", "Amit", "Vijay", "Arjun"],
    "age": [25, 23, 28 , 0,27,26, 24, 29, 31, 22]
})

# %%
df
# Out:
#      name  age
# 0   Pavan   25
# 1   Kumar   23
# 2    Anil   28
# 3    Ravi   30
# 4  Suresh   27
# 5  Mahesh   26
# 6   Rohit   24
# 7    Amit   29
# 8   Vijay   31
# 9   Arjun   22

# %%
df.isnull()
# Out:
#     name    age
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False
# 5  False  False
# 6  False  False
# 7  False  False
# 8  False  False
# 9  False  False

# %%
df.head()
# Out:
#      name  age
# 0   Pavan   25
# 1   Kumar   23
# 2    Anil   28
# 3    Ravi   30
# 4  Suresh   27

# %%
df.tail()
# Out:
#      name  age
# 5  Mahesh   26
# 6   Rohit   24
# 7    Amit   29
# 8   Vijay   31
# 9   Arjun   22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    10 non-null     object
#  1   age     10 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 292.0+ bytes

# %%
df.shape
# Out:
# (10, 2)

# %%
Give
